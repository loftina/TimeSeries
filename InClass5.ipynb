# %%
x_t <- rep(0, 100)
alpha <- .3
for (i in 2:100) {
    x_t[i] <- alpha*x_t[i-1] + rnorm(n=1)
}

# %%
x_t <- ts(x_t)
plot(x_t)
# Out:
# plot without title

# %%
Generate <- function(rho) {
    x <- rep(0, 100)
    x[1] <- 0
    for (i in 2:100) {
        x[i] <- rho * x[i-1] + rnorm(1)
    }
}
